# %%
#import pandas as pd
import pandas as pd

#download .csv
url = 'https://raw.githubusercontent.com/LLBartlett/HealthReach/master/HealthReach_Languages.csv'

df1 = pd.read_csv(url)

df1
# Out:
#                                Language Name   \
# 0                                    Albanian
# 1                                    Amharic
# 2                                     Arabic
# 3                                   Armenian
# 4                                    Bengali
# 5                                    Bosnian
# 6                                    Burmese
# 7                         Cape Verdean Creole
# 8      Chinese, Simplified (Mandarin dialect)
# 9   Chinese, Traditional (Cantonese dialect)
# 10                                  Chuukese
# 11                                   Croatian
# 12                                      Dari
# 13                                  Dzongkha
# 14                                   English
# 15                                     Farsi
# 16                                    French
# 17                                    German
# 18                                  Gujarati
# 19                             Haitian Creole
# ...
